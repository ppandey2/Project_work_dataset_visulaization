# %% [markdown]
# ## Python Project on Corona Virus Spread through SQL, Python and Visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('case.csv')

# %%
a.describe()
# Out:
#          case_id    confirmed
# count  77.000000    77.000000
# mean   39.000000    98.935065
# std    22.371857   485.716707
# min     1.000000     1.000000
# 25%    20.000000     3.000000
# 50%    39.000000     8.000000
# 75%    58.000000    17.000000
# max    77.000000  4096.000000

# %%
a.head()
# Out:
#    case_id province          city  group                 infection_case  \
# 0        1    Seoul       Guro-gu   True            Guro-gu Call Center
# 1        2    Seoul  Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
# 2        3    Seoul  Seongdong-gu   True               Seongdong-gu APT
# 3        4    Seoul     Jongno-gu   True        Jongno Community Center
# 4        5    Seoul       Jung-gu   True        Jung-gu Fashion Company
#
#    confirmed   latitude   longitude
# 0         53  37.508163  126.884387
# 1         14   37.63369    126.9165
# 2         13   37.55713    127.0403
# 3         10   37.57681     127.006
# 4          7  37.562405  126.984377

# %%
a.count()
# Out:
# case_id           77
# province          77
# city              77
# group             77
# infection_case    77
# confirmed         77
# latitude          75
# longitude         75
# dtype: int64

# %%
a.province.unique()
# Out:
# array(['Seoul', 'Busan', 'Daegu', 'Incheon', 'Gwangju', 'Daejeon',
#        'Ulsan', 'Sejong', 'Gyeonggi-do', 'Gangwon-do',
#        'Chungcheongbuk-do', 'Chungcheongnam-do', 'Jeollabuk-do',
#        'Jeollanam-do', 'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Jeju-do'],
#       dtype=object)

# %%
a.groupby('province').count()
# Out:
#                    case_id  city  group  infection_case  confirmed  latitude  \
# province
# Busan                    7     7      7               7          7         7
# Chungcheongbuk-do        4     4      4               4          4         4
# Chungcheongnam-do        3     3      3               3          3         3
# Daegu                    4     4      4               4          4         4
# Daejeon                  3     3      3               3          3         3
# Gangwon-do               3     3      3               3          3         2
# Gwangju                  3     3      3               3          3         3
# Gyeonggi-do              6     6      6               6          6         6
# Gyeongsangbuk-do         9     9      9               9          9         9
# Gyeongsangnam-do         7     7      7               7          7         7
# Incheon                  5     5      5               5          5         5
# ...

# %%
a['freq'] = a.groupby('province')['province'].transform('count')

# %%
a.head(2)
# Out:
#    case_id province          city  group                 infection_case  \
# 0        1    Seoul       Guro-gu   True            Guro-gu Call Center
# 1        2    Seoul  Eunpyeong-gu   True  Eunpyeong St. Mary's Hospital
#
#    confirmed   latitude   longitude  freq
# 0         53  37.508163  126.884387     8
# 1         14   37.63369    126.9165     8

# %%
a.freq
# Out:
# 0     8
# 1     8
# 2     8
# 3     8
# 4     8
#      ..
# 72    7
# 73    7
# 74    7
# 75    7
# 76    1
# Name: freq, Length: 77, dtype: int64

# %%
df1 = a[['province','freq']]
# Out:
#   province  freq
# 0    Seoul     8
# 1    Seoul     8
# 2    Seoul     8

# %%
df1
# Out:
#             province  freq
# 0              Seoul     8
# 1              Seoul     8
# 2              Seoul     8
# 3              Seoul     8
# 4              Seoul     8
# ..               ...   ...
# 72  Gyeongsangnam-do     7
# 73  Gyeongsangnam-do     7
# 74  Gyeongsangnam-do     7
# 75  Gyeongsangnam-do     7
# 76           Jeju-do     1
#
# [77 rows x 2 columns]

# %%
count = df1['province'].value_counts()

# %%
count
# Out:
# Gyeongsangbuk-do     9
# Seoul                8
# Gyeongsangnam-do     7
# Busan                7
# Gyeonggi-do          6
# Incheon              5
# Jeollabuk-do         4
# Chungcheongbuk-do    4
# Jeollanam-do         4
# Daegu                4
# Daejeon              3
# Gangwon-do           3
# Chungcheongnam-do    3
# Gwangju              3
# Ulsan                3
# Sejong               3
# Jeju-do              1
# Name: province, dtype: int64

# %%
type(count)
# Out:
# pandas.core.series.Series

# %%
#plt.bar(count, align='center', alpha=1)

# %%
ax = count.plot.bar(rot=80)
